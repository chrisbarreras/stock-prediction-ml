# %%
# Cell 1: Imports and Configuration
import pandas as pd
import numpy as np
import yfinance as yf
import pickle
import os
import time
import shutil
import warnings
warnings.filterwarnings('ignore')

DATA_DIR = os.path.join('..', 'data')
START_DATE = '2009-01-01'
SLEEP_TIME = 0.5  # seconds between requests

print(f'yfinance version: {yf.__version__}')
print(f'Data directory: {os.path.abspath(DATA_DIR)}')
print(f'Download range: {START_DATE} to present')
# Out:
# yfinance version: 0.2.35
# Data directory: c:\Users\chris\stock-prediction-ml\data
# Download range: 2009-01-01 to present

# %%
# Cell 2: Get S&P 500 Ticker List from Wikipedia
import requests
from io import StringIO

url = 'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies'
headers = {'User-Agent': 'Mozilla/5.0 (stock-prediction-ml project)'}
response = requests.get(url, headers=headers)
response.raise_for_status()

tables = pd.read_html(StringIO(response.text))
sp500_df = tables[0]

print(f'Columns: {list(sp500_df.columns)}')
print(f'Total companies: {len(sp500_df)}')

# Extract tickers - handle special characters
sp500_tickers = sp500_df['Symbol'].str.replace('.', '-', regex=False).tolist()

# Show sector breakdown
print(f'\nSectors:')
for sector, count in sp500_df['GICS Sector'].value_counts().items():
    print(f'  {sector}: {count}')

print(f'\nFirst 10 tickers: {sp500_tickers[:10]}')
# Out:
# Columns: ['Symbol', 'Security', 'GICS Sector', 'GICS Sub-Industry', 'Headquarters Location', 'Date added', 'CIK', 'Founded']
# Total companies: 503
#
# Sectors:
#   Industrials: 79
#   Financials: 76
#   Information Technology: 71
#   Health Care: 60
#   Consumer Discretionary: 48
#   Consumer Staples: 36
#   Utilities: 31
#   Real Estate: 31
#   Materials: 26
#   Communication Services: 23
#   Energy: 22
#
# First 10 tickers: ['MMM', 'AOS', 'ABT', 'ABBV', 'ACN', 'ADBE', 'AMD', 'AES', 'AFL', 'A']

# %%
# Cell 3: Download Price Data (batch mode)
price_data = {}
failed_tickers = []

# Download in batches of 50 tickers at a time
BATCH_SIZE = 50
total = len(sp500_tickers)
print(f'Downloading {total} tickers in batches of {BATCH_SIZE}...\n')

for batch_start in range(0, total, BATCH_SIZE):
    batch = sp500_tickers[batch_start:batch_start + BATCH_SIZE]
    batch_num = batch_start // BATCH_SIZE + 1
    print(f'  Batch {batch_num}: tickers {batch_start+1}-{batch_start+len(batch)}...', end=' ')
    
    try:
        df = yf.download(
            batch, 
            start=START_DATE, 
            auto_adjust=False, 
            group_by='ticker', 
            threads=False,
            progress=False
        )
        
        if len(batch) == 1:
            # Single ticker - no MultiIndex on columns
            ticker = batch[0]
            if len(df) > 100:
                sub = df[['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']].copy()
                sub.index = sub.index.tz_localize(None) if sub.index.tz else sub.index
                price_data[ticker] = sub
        else:
            # Multiple tickers - MultiIndex columns (Ticker, Price)
            for ticker in batch:
                try:
                    sub = df[ticker][['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']].copy()
                    sub = sub.dropna(how='all')
                    if len(sub) > 100:
                        sub.index = sub.index.tz_localize(None) if sub.index.tz else sub.index
                        price_data[ticker] = sub
                    else:
                        failed_tickers.append(ticker)
                except Exception:
                    failed_tickers.append(ticker)
        
        print(f'{len(price_data)} total successful')
    except Exception as e:
        print(f'BATCH FAILED: {e}')
        failed_tickers.extend(batch)
    
    time.sleep(2)  # pause between batches

print(f'\n=== Download Complete ===')
print(f'Successful: {len(price_data)}')
print(f'Failed: {len(failed_tickers)}')
if failed_tickers:
    print(f'Failed tickers: {failed_tickers[:20]}')
# Out:
# Downloading 503 tickers in batches of 50...
#
#   Batch 1: tickers 1-50...
# Failed to get ticker 'APH' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'AOS' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'ARE' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'APD' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'ALLE' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'AKAM' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'APTV' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'AIG' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'ANET' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'AIZ' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'ALGN' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'AWK' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'AMZN' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'AEE' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'AMCR' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'ALB' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'AMAT' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'AES' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'ABT' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'AME' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'AAPL' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'A' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'LNT' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'ALL' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'AMP' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'APO' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'AMGN' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'AON' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'GOOG' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'ATO' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'AXP' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'ACGL' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'ABNB' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'ARES' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'ACN' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'AMD' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'MO' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'AEP' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'ADBE' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'AMT' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'APP' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'ADM' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'GOOGL' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'APA' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'ABBV' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'MMM' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'AFL' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'T' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'AJG' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'ADI' reason: Expecting value: line 1 column 1 (char 0)
#
# 50 Failed downloads:
# ['APH', 'AOS', 'ARE', 'APD', 'ALLE', 'AKAM', 'APTV', 'AIG', 'ANET', 'AIZ', 'ALGN', 'AWK', 'AMZN', 'AEE', 'AMCR', 'ALB', 'AMAT', 'AES', 'ABT', 'AME', 'AAPL', 'A', 'LNT', 'ALL', 'AMP', 'APO', 'AMGN', 'AON', 'GOOG', 'ATO', 'AXP', 'ACGL', 'ABNB', 'ARES', 'ACN', 'AMD', 'MO', 'AEP', 'ADBE', 'AMT', 'APP', 'ADM', 'GOOGL', 'APA', 'ABBV', 'MMM', 'AFL', 'T', 'AJG', 'ADI']: Exception('%ticker%: No timezone found, symbol may be delisted')
# 0 total successful
#   Batch 2: tickers 51-100...
# Failed to get ticker 'ADP' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'BBY' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'BLK' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'CNP' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'BG' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'CARR' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'BRO' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'CAH' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'CRL' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'CHTR' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'CPB' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'CVNA' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'BIIB' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'BK' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'SCHW' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'BAC' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'AVGO' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'BA' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'AXON' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'CPT' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'CBRE' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'CF' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'BALL' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'BSX' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'BRK-B' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'BXP' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'CHRW' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'BR' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'CDNS' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'CBOE' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'CCL' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'BKNG' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'XYZ' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'CNC' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'CDW' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'BLDR' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'COF' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'AZO' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'BX' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'BMY' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'BAX' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'ADSK' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'TECH' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'AVY' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'CAT' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'AVB' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'BKR' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'COR' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'BF-B' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'BDX' reason: Expecting value: line 1 column 1 (char 0)
#
# 50 Failed downloads:
# ['ADP', 'BBY', 'BLK', 'CNP', 'BG', 'CARR', 'BRO', 'CAH', 'CRL', 'CHTR', 'CPB', 'CVNA', 'BIIB', 'BK', 'SCHW', 'BAC', 'AVGO', 'BA', 'AXON', 'CPT', 'CBRE', 'CF', 'BALL', 'BSX', 'BRK-B', 'BXP', 'CHRW', 'BR', 'CDNS', 'CBOE', 'CCL', 'BKNG', 'XYZ', 'CNC', 'CDW', 'BLDR', 'COF', 'AZO', 'BX', 'BMY', 'BAX', 'ADSK', 'TECH', 'AVY', 'CAT', 'AVB', 'BKR', 'COR', 'BF-B', 'BDX']: Exception('%ticker%: No timezone found, symbol may be delisted')
# 0 total successful
#   Batch 3: tickers 101-150...
# Failed to get ticker 'COP' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'KO' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'CSCO' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'DXCM' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'ED' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'DELL' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'CINF' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'CPRT' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'CIEN' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'CLX' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'STZ' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'DVA' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'CAG' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'CVS' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'DHR' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'DRI' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'DDOG' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'CMCSA' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'DVN' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'DECK' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'CRWD' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'COIN' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'COST' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'CTRA' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'CEG' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'FANG' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'CFG' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'CHD' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'CSGP' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'COO' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'DE' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'CTVA' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'CME' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'CMI' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'C' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'GLW' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'CI' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'CB' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'CSX' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'CTAS' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'CPAY' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'CMG' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'FIX' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'DAL' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'CCI' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'CMS' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'CTSH' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'CVX' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'CRH' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'CL' reason: Expecting value: line 1 column 1 (char 0)
#
# 50 Failed downloads:
# ['COP', 'KO', 'CSCO', 'DXCM', 'ED', 'DELL', 'CINF', 'CPRT', 'CIEN', 'CLX', 'STZ', 'DVA', 'CAG', 'CVS', 'DHR', 'DRI', 'DDOG', 'CMCSA', 'DVN', 'DECK', 'CRWD', 'COIN', 'COST', 'CTRA', 'CEG', 'FANG', 'CFG', 'CHD', 'CSGP', 'COO', 'DE', 'CTVA', 'CME', 'CMI', 'C', 'GLW', 'CI', 'CB', 'CSX', 'CTAS', 'CPAY', 'CMG', 'FIX', 'DAL', 'CCI', 'CMS', 'CTSH', 'CVX', 'CRH', 'CL']: Exception('%ticker%: No timezone found, symbol may be delisted')
# 0 total successful
#   Batch 4: tickers 151-200...
# Failed to get ticker 'ETN' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'EMR' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'DG' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'FDS' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'FAST' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'DUK' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'EL' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'FITB' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'EXC' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'DHI' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'EW' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'ELV' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'EPAM' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'EXE' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'EQT' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'DTE' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'EA' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'EFX' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'FFIV' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'EG' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'DOV' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'DD' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'ES' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'EXPE' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'EQIX' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'EME' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'FIS' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'EBAY' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'EOG' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'DLTR' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'DASH' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'FRT' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'FSLR' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'EXPD' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'FE' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'DOW' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'FDX' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'DPZ' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'ESS' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'ETR' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'EXR' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'XOM' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'EQR' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'DLR' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'EVRG' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'EIX' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'D' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'ECL' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'ERIE' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'FICO' reason: Expecting value: line 1 column 1 (char 0)
#
# 50 Failed downloads:
# ['ETN', 'EMR', 'DG', 'FDS', 'FAST', 'DUK', 'EL', 'FITB', 'EXC', 'DHI', 'EW', 'ELV', 'EPAM', 'EXE', 'EQT', 'DTE', 'EA', 'EFX', 'FFIV', 'EG', 'DOV', 'DD', 'ES', 'EXPE', 'EQIX', 'EME', 'FIS', 'EBAY', 'EOG', 'DLTR', 'DASH', 'FRT', 'FSLR', 'EXPD', 'FE', 'DOW', 'FDX', 'DPZ', 'ESS', 'ETR', 'EXR', 'XOM', 'EQR', 'DLR', 'EVRG', 'EIX', 'D', 'ECL', 'ERIE', 'FICO']: Exception('%ticker%: No timezone found, symbol may be delisted')
# 0 total successful
#   Batch 5: tickers 201-250...
# Failed to get ticker 'IBM' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'GEHC' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'GDDY' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'HPE' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'IEX' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'HIG' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'GS' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'HBAN' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'HSY' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'GNRC' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'BEN' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'GPC' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'INCY' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'GEN' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'FTV' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'GE' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'GM' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'HD' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'FOX' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'HWM' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'HON' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'HUBB' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'FOXA' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'IDXX' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'GEV' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'GIS' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'HII' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'HRL' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'F' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'HST' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'HUM' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'GILD' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'IR' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'HOLX' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'HAL' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'HAS' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'HPQ' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'HLT' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'HCA' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'HSIC' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'GD' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'FCX' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'ITW' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'FISV' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'FTNT' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'GPN' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'DOC' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'GRMN' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'IT' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'GL' reason: Expecting value: line 1 column 1 (char 0)
#
# 50 Failed downloads:
# ['IBM', 'GEHC', 'GDDY', 'HPE', 'IEX', 'HIG', 'GS', 'HBAN', 'HSY', 'GNRC', 'BEN', 'GPC', 'INCY', 'GEN', 'FTV', 'GE', 'GM', 'HD', 'FOX', 'HWM', 'HON', 'HUBB', 'FOXA', 'IDXX', 'GEV', 'GIS', 'HII', 'HRL', 'F', 'HST', 'HUM', 'GILD', 'IR', 'HOLX', 'HAL', 'HAS', 'HPQ', 'HLT', 'HCA', 'HSIC', 'GD', 'FCX', 'ITW', 'FISV', 'FTNT', 'GPN', 'DOC', 'GRMN', 'IT', 'GL']: Exception('%ticker%: No timezone found, symbol may be delisted')
# 0 total successful
#   Batch 6: tickers 251-300...
# Failed to get ticker 'KDP' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'KMB' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'LHX' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'LII' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'LLY' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'MAR' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'LULU' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'IP' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'IVZ' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'LYB' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'JKHY' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'ISRG' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'IRM' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'LOW' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'JCI' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'KR' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'KEY' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'IFF' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'KMI' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'LRCX' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'L' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'KKR' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'J' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'KLAC' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'INVH' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'LDOS' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'MPC' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'MRSH' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'LIN' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'JBHT' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'IQV' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'IBKR' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'INTC' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'LEN' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'LVS' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'JBL' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'LH' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'KIM' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'LMT' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'INTU' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'KEYS' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'JNJ' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'ICE' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'MTB' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'KHC' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'PODD' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'JPM' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'LW' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'LYV' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'KVUE' reason: Expecting value: line 1 column 1 (char 0)
#
# 50 Failed downloads:
# ['KDP', 'KMB', 'LHX', 'LII', 'LLY', 'MAR', 'LULU', 'IP', 'IVZ', 'LYB', 'JKHY', 'ISRG', 'IRM', 'LOW', 'JCI', 'KR', 'KEY', 'IFF', 'KMI', 'LRCX', 'L', 'KKR', 'J', 'KLAC', 'INVH', 'LDOS', 'MPC', 'MRSH', 'LIN', 'JBHT', 'IQV', 'IBKR', 'INTC', 'LEN', 'LVS', 'JBL', 'LH', 'KIM', 'LMT', 'INTU', 'KEYS', 'JNJ', 'ICE', 'MTB', 'KHC', 'PODD', 'JPM', 'LW', 'LYV', 'KVUE']: Exception('%ticker%: No timezone found, symbol may be delisted')
# 0 total successful
#   Batch 7: tickers 301-350...
# Failed to get ticker 'MTCH' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'MTD' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'MRK' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'MGM' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'TAP' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'NXPI' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'NKE' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'MCK' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'MA' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'MSI' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'MOS' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'MLM' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'META' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'MPWR' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'NFLX' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'OXY' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'NVDA' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'MCO' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'MU' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'NEE' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'MS' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'NDSN' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'MAS' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'MRNA' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'MAA' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'NTRS' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'MKC' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'MOH' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'NWSA' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'MDLZ' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'NTAP' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'MSCI' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'NDAQ' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'NWS' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'ORLY' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'MCHP' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'MSFT' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'MCD' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'NEM' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'NOC' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'NUE' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'NRG' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'NVR' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'MET' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'MNST' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'ODFL' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'NSC' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'NI' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'NCLH' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'MDT' reason: Expecting value: line 1 column 1 (char 0)
#
# 50 Failed downloads:
# ['MTCH', 'MTD', 'MRK', 'MGM', 'TAP', 'NXPI', 'NKE', 'MCK', 'MA', 'MSI', 'MOS', 'MLM', 'META', 'MPWR', 'NFLX', 'OXY', 'NVDA', 'MCO', 'MU', 'NEE', 'MS', 'NDSN', 'MAS', 'MRNA', 'MAA', 'NTRS', 'MKC', 'MOH', 'NWSA', 'MDLZ', 'NTAP', 'MSCI', 'NDAQ', 'NWS', 'ORLY', 'MCHP', 'MSFT', 'MCD', 'NEM', 'NOC', 'NUE', 'NRG', 'NVR', 'MET', 'MNST', 'ODFL', 'NSC', 'NI', 'NCLH', 'MDT']: Exception('%ticker%: No timezone found, symbol may be delisted')
# 0 total successful
#   Batch 8: tickers 351-400...
# Failed to get ticker 'PM' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'PNR' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'RTX' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'RMD' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'PEP' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'REGN' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'PAYX' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'PSX' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'PCG' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'PFG' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'ON' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'PCAR' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'ROK' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'PNC' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'PHM' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'POOL' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'REG' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'RVTY' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'PANW' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'PSA' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'PYPL' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'RF' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'HOOD' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'PH' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'PTC' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'PLD' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'PRU' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'PPL' reason: Expecting value: line 1 column 1 (char 0)
# Failed to get ticker 'RL' reason: Expecting value: line 1 column 1 (char 0)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 16
#      13 print(f'  Batch {batch_num}: tickers {batch_start+1}-{batch_start+len(batch)}...', end=' ')
#      15 try:
# ---> 16     df = yf.download(
#      17         batch,
#      18         start=START_DATE,
#      19         auto_adjust=False,
#      20         group_by='ticker',
#      21         threads=False,
#      22         progress=False
#      23     )
#      25     if len(batch) == 1:
#      26         # Single ticker - no MultiIndex on columns
#      27         ticker = batch[0]
#
# File c:\Users\chris\stock-prediction-ml\venv\Lib\site-packages\yfinance\utils.py:103, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#     100 logger.debug(f'Entering {func.__name__}()')
#     102 with IndentationContext():
# --> 103     result = func(*args, **kwargs)
#     105 logger.debug(f'Exiting {func.__name__}()')
#     106 return result
#
# File c:\Users\chris\stock-prediction-ml\venv\Lib\site-packages\yfinance\multi.py:167, in download(tickers, start, end, actions, threads, ignore_tz, group_by, auto_adjust, back_adjust, repair, keepna, progress, period, show_errors, interval, prepost, proxy, rounding, timeout, session)
#     164 # download synchronously
#     165 else:
#     166     for i, ticker in enumerate(tickers):
# --> 167         data = _download_one(ticker, period=period, interval=interval,
#     168                              start=start, end=end, prepost=prepost,
#     169                              actions=actions, auto_adjust=auto_adjust,
#     170                              back_adjust=back_adjust, repair=repair, keepna=keepna,
#     171                              proxy=proxy,
#     172                              rounding=rounding, timeout=timeout)
#     173         if progress:
#     174             shared._PROGRESS_BAR.animate()
#
# File c:\Users\chris\stock-prediction-ml\venv\Lib\site-packages\yfinance\multi.py:279, in _download_one(ticker, start, end, auto_adjust, back_adjust, repair, actions, period, interval, prepost, proxy, rounding, keepna, timeout)
#     277 data = None
#     278 try:
# --> 279     data = Ticker(ticker).history(
#     280             period=period, interval=interval,
#     281             start=start, end=end, prepost=prepost,
#     282             actions=actions, auto_adjust=auto_adjust,
#     283             back_adjust=back_adjust, repair=repair, proxy=proxy,
#     284             rounding=rounding, keepna=keepna, timeout=timeout,
#     285             raise_errors=True
#     286     )
#     287 except Exception as e:
#     288     # glob try/except needed as current thead implementation breaks if exception is raised.
#     289     shared._DFS[ticker.upper()] = utils.empty_df()
#
# File c:\Users\chris\stock-prediction-ml\venv\Lib\site-packages\yfinance\utils.py:103, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#     100 logger.debug(f'Entering {func.__name__}()')
#     102 with IndentationContext():
# --> 103     result = func(*args, **kwargs)
#     105 logger.debug(f'Exiting {func.__name__}()')
#     106 return result
#
# File c:\Users\chris\stock-prediction-ml\venv\Lib\site-packages\yfinance\base.py:138, in TickerBase.history(self, period, interval, start, end, prepost, actions, auto_adjust, back_adjust, repair, keepna, proxy, rounding, timeout, raise_errors)
#     135 end_user = end
#     136 if start or period is None or period.lower() == "max":
#     137     # Check can get TZ. Fail => probably delisted
# --> 138     tz = self._get_ticker_tz(proxy, timeout)
#     139     if tz is None:
#     140         # Every valid ticker has a timezone. Missing = problem
#     141         err_msg = "No timezone found, symbol may be delisted"
#
# File c:\Users\chris\stock-prediction-ml\venv\Lib\site-packages\yfinance\base.py:1656, in TickerBase._get_ticker_tz(self, proxy, timeout)
#    1653     tz = None
#    1655 if tz is None:
# -> 1656     tz = self._fetch_ticker_tz(proxy, timeout)
#    1658     if utils.is_valid_timezone(tz):
#    1659         # info fetch is relatively slow so cache timezone
#    1660         c.store(self.ticker, tz)
#
# File c:\Users\chris\stock-prediction-ml\venv\Lib\site-packages\yfinance\utils.py:103, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#     100 logger.debug(f'Entering {func.__name__}()')
#     102 with IndentationContext():
# --> 103     result = func(*args, **kwargs)
#     105 logger.debug(f'Exiting {func.__name__}()')
#     106 return result
#
# File c:\Users\chris\stock-prediction-ml\venv\Lib\site-packages\yfinance\base.py:1679, in TickerBase._fetch_ticker_tz(self, proxy, timeout)
#    1676 url = f"{self._base_url}/v8/finance/chart/{self.ticker}"
#    1678 try:
# -> 1679     data = self._data.cache_get(url=url, params=params, proxy=proxy, timeout=timeout)
#    1680     data = data.json()
#    1681 except Exception as e:
#
# File c:\Users\chris\stock-prediction-ml\venv\Lib\site-packages\yfinance\data.py:28, in lru_cache_freezeargs.<locals>.wrapped(*args, **kwargs)
#      26 args = tuple([tuple(arg) if isinstance(arg, list) else arg for arg in args])
#      27 kwargs = {k: tuple(v) if isinstance(v, list) else v for k, v in kwargs.items()}
# ---> 28 return func(*args, **kwargs)
#
# File c:\Users\chris\stock-prediction-ml\venv\Lib\site-packages\yfinance\data.py:387, in YfData.cache_get(self, url, user_agent_headers, params, proxy, timeout)
#     384 @lru_cache_freezeargs
#     385 @lru_cache(maxsize=cache_maxsize)
#     386 def cache_get(self, url, user_agent_headers=None, params=None, proxy=None, timeout=30):
# --> 387     return self.get(url, user_agent_headers, params, proxy, timeout)
#
# File c:\Users\chris\stock-prediction-ml\venv\Lib\site-packages\yfinance\utils.py:103, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#     100 logger.debug(f'Entering {func.__name__}()')
#     102 with IndentationContext():
# --> 103     result = func(*args, **kwargs)
#     105 logger.debug(f'Exiting {func.__name__}()')
#     106 return result
#
# File c:\Users\chris\stock-prediction-ml\venv\Lib\site-packages\yfinance\data.py:375, in YfData.get(self, url, user_agent_headers, params, proxy, timeout)
#     373 else:
#     374     self._set_cookie_strategy('basic')
# --> 375 cookie, crumb, strategy = self._get_cookie_and_crumb(proxy, timeout)
#     376 request_args['params']['crumb'] = crumb
#     377 if strategy == 'basic':
#
# File c:\Users\chris\stock-prediction-ml\venv\Lib\site-packages\yfinance\utils.py:103, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#     100 logger.debug(f'Entering {func.__name__}()')
#     102 with IndentationContext():
# --> 103     result = func(*args, **kwargs)
#     105 logger.debug(f'Exiting {func.__name__}()')
#     106 return result
#
# File c:\Users\chris\stock-prediction-ml\venv\Lib\site-packages\yfinance\data.py:317, in YfData._get_cookie_and_crumb(self, proxy, timeout)
#     315 with self._cookie_lock:
#     316     if self._cookie_strategy == 'csrf':
# --> 317         crumb = self._get_crumb_csrf()
#     318         if crumb is None:
#     319             # Fail
#     320             self._set_cookie_strategy('basic', have_lock=True)
#
# File c:\Users\chris\stock-prediction-ml\venv\Lib\site-packages\yfinance\utils.py:103, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#     100 logger.debug(f'Entering {func.__name__}()')
#     102 with IndentationContext():
# --> 103     result = func(*args, **kwargs)
#     105 logger.debug(f'Exiting {func.__name__}()')
#     106 return result
#
# File c:\Users\chris\stock-prediction-ml\venv\Lib\site-packages\yfinance\data.py:286, in YfData._get_crumb_csrf(self, proxy, timeout)
#     283     utils.get_yf_logger().debug('reusing crumb')
#     284     return self._crumb
# --> 286 if not self._get_cookie_csrf(proxy, timeout):
#     287     # This cookie stored in session
#     288     return None
#     290 get_args = {
#     291     'url': 'https://query2.finance.yahoo.com/v1/test/getcrumb',
#     292     'headers': self.user_agent_headers,
#     293     'proxies': proxy,
#     294     'timeout': timeout}
#
# File c:\Users\chris\stock-prediction-ml\venv\Lib\site-packages\yfinance\data.py:237, in YfData._get_cookie_csrf(self, proxy, timeout)
#     235     response = self._session.get(**get_args)
#     236 else:
# --> 237     response = self._session.get(**get_args)
#     239 soup = BeautifulSoup(response.content, 'html.parser')
#     240 csrfTokenInput = soup.find('input', attrs={'name': 'csrfToken'})
#
# File c:\Users\chris\stock-prediction-ml\venv\Lib\site-packages\requests\sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File c:\Users\chris\stock-prediction-ml\venv\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\chris\stock-prediction-ml\venv\Lib\site-packages\requests\sessions.py:725, in Session.send(self, request, **kwargs)
#     722 if allow_redirects:
#     723     # Redirect resolving generator.
#     724     gen = self.resolve_redirects(r, request, **kwargs)
# --> 725     history = [resp for resp in gen]
#     726 else:
#     727     history = []
#
# File c:\Users\chris\stock-prediction-ml\venv\Lib\site-packages\requests\sessions.py:266, in SessionRedirectMixin.resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, yield_requests, **adapter_kwargs)
#     263     yield req
#     264 else:
# --> 266     resp = self.send(
#     267         req,
#     268         stream=stream,
#     269         timeout=timeout,
#     270         verify=verify,
#     271         cert=cert,
#     272         proxies=proxies,
#     273         allow_redirects=False,
#     274         **adapter_kwargs,
#     275     )
#     277     extract_cookies_to_jar(self.cookies, prepared_request, resp.raw)
#     279     # extract redirect url, if any, for the next loop
#
# File c:\Users\chris\stock-prediction-ml\venv\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\chris\stock-prediction-ml\venv\Lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File c:\Users\chris\stock-prediction-ml\venv\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File c:\Users\chris\stock-prediction-ml\venv\Lib\site-packages\urllib3\connectionpool.py:464, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     461 try:
#     462     # Trigger any extra validation we need to do.
#     463     try:
# --> 464         self._validate_conn(conn)
#     465     except (SocketTimeout, BaseSSLError) as e:
#     466         self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File c:\Users\chris\stock-prediction-ml\venv\Lib\site-packages\urllib3\connectionpool.py:1093, in HTTPSConnectionPool._validate_conn(self, conn)
#    1091 # Force connect early to allow us to validate the connection.
#    1092 if conn.is_closed:
# -> 1093     conn.connect()
#    1095 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#    1096 if not conn.is_verified and not conn.proxy_is_verified:
#
# File c:\Users\chris\stock-prediction-ml\venv\Lib\site-packages\urllib3\connection.py:796, in HTTPSConnection.connect(self)
#     793     # Remove trailing '.' from fqdn hostnames to allow certificate validation
#     794     server_hostname_rm_dot = server_hostname.rstrip(".")
# --> 796     sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#     797         sock=sock,
#     798         cert_reqs=self.cert_reqs,
#     799         ssl_version=self.ssl_version,
#     800         ssl_minimum_version=self.ssl_minimum_version,
#     801         ssl_maximum_version=self.ssl_maximum_version,
#     802         ca_certs=self.ca_certs,
#     803         ca_cert_dir=self.ca_cert_dir,
#     804         ca_cert_data=self.ca_cert_data,
#     805         cert_file=self.cert_file,
#     806         key_file=self.key_file,
#     807         key_password=self.key_password,
#     808         server_hostname=server_hostname_rm_dot,
#     809         ssl_context=self.ssl_context,
#     810         tls_in_tls=tls_in_tls,
#     811         assert_hostname=self.assert_hostname,
#     812         assert_fingerprint=self.assert_fingerprint,
#     813     )
#     814     self.sock = sock_and_verified.socket
#     816 # If an error occurs during connection/handshake we may need to release
#     817 # our lock so another connection can probe the origin.
#
# File c:\Users\chris\stock-prediction-ml\venv\Lib\site-packages\urllib3\connection.py:975, in _ssl_wrap_socket_and_match_hostname(sock, cert_reqs, ssl_version, ssl_minimum_version, ssl_maximum_version, cert_file, key_file, key_password, ca_certs, ca_cert_dir, ca_cert_data, assert_hostname, assert_fingerprint, server_hostname, ssl_context, tls_in_tls)
#     972     if is_ipaddress(normalized):
#     973         server_hostname = normalized
# --> 975 ssl_sock = ssl_wrap_socket(
#     976     sock=sock,
#     977     keyfile=key_file,
#     978     certfile=cert_file,
#     979     key_password=key_password,
#     980     ca_certs=ca_certs,
#     981     ca_cert_dir=ca_cert_dir,
#     982     ca_cert_data=ca_cert_data,
#     983     server_hostname=server_hostname,
#     984     ssl_context=context,
#     985     tls_in_tls=tls_in_tls,
#     986 )
#     988 try:
#     989     if assert_fingerprint:
#
# File c:\Users\chris\stock-prediction-ml\venv\Lib\site-packages\urllib3\util\ssl_.py:461, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     459 if ca_certs or ca_cert_dir or ca_cert_data:
#     460     try:
# --> 461         context.load_verify_locations(ca_certs, ca_cert_dir, ca_cert_data)
#     462     except OSError as e:
#     463         raise SSLError(e) from e
#
# KeyboardInterrupt:

# %%
# Cell 4: Retry Failed Tickers (one at a time using Ticker object)
if failed_tickers:
    print(f'Retrying {len(failed_tickers)} failed tickers individually...\n')
    still_failed = []
    for ticker in failed_tickers:
        try:
            time.sleep(1)
            t = yf.Ticker(ticker)
            df = t.history(start=START_DATE, auto_adjust=False)
            if len(df) > 100:
                df.index = df.index.tz_localize(None) if df.index.tz else df.index
                cols = [c for c in ['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'] if c in df.columns]
                price_data[ticker] = df[cols].copy()
                print(f'  Recovered: {ticker}')
            else:
                still_failed.append(ticker)
        except:
            still_failed.append(ticker)
    
    print(f'\nRecovered: {len(failed_tickers) - len(still_failed)}')
    if still_failed:
        print(f'Still failed ({len(still_failed)}): {still_failed[:20]}')
else:
    print('No failed tickers to retry.')

print(f'\nTotal tickers with price data: {len(price_data)}')

# %%
# Cell 5: Data Quality Report
print('=== DATA QUALITY REPORT ===')
print(f'Total tickers: {len(price_data)}')

# Date range summary
date_ranges = []
for ticker, df in price_data.items():
    date_ranges.append({
        'ticker': ticker,
        'start': df.index.min(),
        'end': df.index.max(),
        'trading_days': len(df)
    })

dr = pd.DataFrame(date_ranges)
print(f'\nDate Coverage:')
print(f'  Earliest start: {dr["start"].min().strftime("%Y-%m-%d")}')
print(f'  Latest end:     {dr["end"].max().strftime("%Y-%m-%d")}')
print(f'  Avg trading days: {dr["trading_days"].mean():.0f}')
print(f'  Min trading days: {dr["trading_days"].min()} ({dr.loc[dr["trading_days"].idxmin(), "ticker"]})')
print(f'  Max trading days: {dr["trading_days"].max()}')

# Sample data
sample_ticker = list(price_data.keys())[0]
print(f'\nSample ({sample_ticker}):')
print(price_data[sample_ticker].tail(3))
print(f'\nColumns: {list(price_data[sample_ticker].columns)}')

# %%
# Cell 6: Backup Old Data and Save
old_path = os.path.join(DATA_DIR, 'price_data.pkl')
backup_path = os.path.join(DATA_DIR, 'price_data_kaggle_backup.pkl')

# Backup existing file
if os.path.exists(old_path) and not os.path.exists(backup_path):
    shutil.copy2(old_path, backup_path)
    print(f'Backed up old price data to {backup_path}')

# Save new price data
with open(old_path, 'wb') as f:
    pickle.dump(price_data, f)

print(f'Saved price_data.pkl: {len(price_data)} tickers')
print(f'File size: {os.path.getsize(old_path) / 1024 / 1024:.1f} MB')

# %%
# Cell 7: Verification
with open(os.path.join(DATA_DIR, 'price_data.pkl'), 'rb') as f:
    loaded = pickle.load(f)

assert isinstance(loaded, dict), 'Expected dict'
sample_key = list(loaded.keys())[0]
sample_df = loaded[sample_key]
assert isinstance(sample_df, pd.DataFrame), 'Expected DataFrame'
assert isinstance(sample_df.index, pd.DatetimeIndex), 'Expected DatetimeIndex'

expected_cols = {'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'}
assert expected_cols.issubset(set(sample_df.columns)), f'Missing columns: {expected_cols - set(sample_df.columns)}'

print('Verification passed!')
print(f'  Tickers: {len(loaded)}')
print(f'  Format: Dict[str, DataFrame]')
print(f'  Columns: {list(sample_df.columns)}')
print(f'  Index type: DatetimeIndex')
print(f'\nReady for notebook 02.')
